# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
from scipy.optimize import fsolve
from utils import *

# %%
N = 10

# exponential decay with 1
D = make_eig_spect(N, beta=1, alpha=1.5, flag=1)
E = calc_eff_regs(D, lambd_max = 0.5)
make_figure2(D,E)

# polynomial decay with 1.5
D = make_eig_spect(N, beta=1, alpha=1.5, flag=0)
E = calc_eff_regs(D, lambd_max = 0.5)
make_figure2(D,E)

# %%
N = 20; P = 20;

# exponential decay with 1
D = make_eig_spect(N, beta=1, alpha=1.5, flag=1)
C = calc_emp_eigs(D, P)
make_figure(D,C)

# + some regularization lambd
D = make_eig_spect(N, beta=1, alpha=1.5, flag=1)
C = calc_emp_eigs(D, P, lambd=1e-6)
make_figure(D,C)

# polynomial decay with 1.5
D = make_eig_spect(N, beta=1, alpha=1.5, flag=0)
C = calc_emp_eigs(D, P)
make_figure(D,C)

# + some regularization lambd
D = make_eig_spect(N, beta=1, alpha=1.5, flag=0)
C = calc_emp_eigs(D, P, lambd=1e-1)
make_figure(D,C)
